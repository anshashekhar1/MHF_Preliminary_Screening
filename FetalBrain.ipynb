# %%
import openai
import base64
import os
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# OpenAI API Key 
openai.api_key = "-"

# List of valid classification labels
VALID_CONDITIONS = [
    "arnold chiari malformation", "arachnoid cyst", "cerebellar hypoplasia", "colpocephaly", 
    "encephalocele", "holoprosencephaly", "hydranencephaly", "intracranial hemorrhage", 
    "intracranial tumor", "mega cisterna magna", "mild ventriculomegaly", "moderate ventriculomegaly", 
    "normal", "polymicrogyria", "severe ventriculomegaly", "vein of galen malformation"
]

def encode_image(image_path):
    """
    Convert an image to base64 encoding for OpenAI Vision API.
    """
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"File not found: {image_path}")
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

def analyze_ultrasound(image_path):
    """
    Analyzes a fetal brain ultrasound image with GPT-4o.
    Returns an analysis report including diagnostic insights.
    """
    try:
        image_base64 = encode_image(image_path)
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": (
                    "You are an AI specializing in pattern recognition in ultrasound images. "
                    "Analyze the given fetal brain ultrasound image and describe any notable visual patterns. "
                    "Match the image to one of the following categories: " + ", ".join(VALID_CONDITIONS) + ". "
                    "Provide your analysis first, and then at the very end, explicitly state the classification in this format:\n\n"
                    "Final Classification: [condition]\n\n"
                    "Do not provide medical advice or diagnostic opinions—only describe visual features and provide the classification."
                )},
                {"role": "user", "content": [
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_base64}"}}
                ]}
            ],
            max_tokens=500
        )
        return response.choices[0].message.content  # Return full analysis and classification
    except Exception as e:
        print(f"Error calling GPT-4o API: {e}")
        return None

def extract_final_classification(analysis_report):
    """
    Extracts the final classification label from the last mention of 'Final Classification:' in the GPT-4o response.
    """
    if not analysis_report:
        return "unknown"

    # Convert report to lowercase and split into lines
    lines = analysis_report.strip().split("\n")

    # Iterate in reverse to find "Final Classification:" and extract the condition
    for line in reversed(lines):
        line = line.strip().lower()
        if "final classification:" in line:
            pred_label = line.split("final classification:")[-1].strip()

            # Remove unwanted punctuation but preserve spaces
            pred_label = re.sub(r"[^\w\s]", "", pred_label)

            # Ensure extracted label is valid
            if pred_label in VALID_CONDITIONS:
                return pred_label
            else:
                print(f"Warning: Extracted invalid classification: '{pred_label}'. Check GPT output format.")

    return "unknown"

def get_ground_truth(row):
    """
    Extract the ground truth label from the dataset, handling multiple labels.
    """
    labels = [col for col in row.index[1:] if row[col] == 1]
    return labels[0] if len(labels) == 1 else "multiple" if labels else "unknown"

def evaluate_gpt4o(dataset_path):
    """
    Evaluates GPT-4o performance on a dataset of images with ground truth labels.
    """
    results = []
    
    # Load dataset (image filenames and one-hot encoded labels)
    dataset = pd.read_csv(dataset_path, encoding="utf-8", on_bad_lines='skip')
    dataset['ground_truth'] = dataset.apply(get_ground_truth, axis=1)
    
    # Process first 20 images for testing
    for _, row in dataset.head(20).iterrows():
        image_path = os.path.join("Fetal Brain Abnormalities Ultrasound.v1i.multiclass", "test", row['filename'])
        true_label = row['ground_truth']
        if os.path.exists(image_path):
            analysis_report = analyze_ultrasound(image_path)
            pred_label = extract_final_classification(analysis_report)
            results.append({"image": image_path, "true_label": true_label, "predicted_label": pred_label, "analysis": analysis_report})
        else:
            print(f"Skipping missing image: {image_path}")
    
    # Convert results to DataFrame
    results_df = pd.DataFrame(results)
    results_df.to_csv("gpt4o_ultrasound_results.csv", index=False)
    
    # Display results
    print("\nGPT-4o Classification Results:")
    for _, row in results_df.iterrows():
        print(f"Filename: {row['image']}")
        print(f"True Label: {row['true_label']}")
        print(f"Predicted Label: {row['predicted_label']}")
        print(f"Analysis: {row['analysis']}")
        print("-" * 80)
    
    # Classification Report
    print("Classification Report:")
    y_true = results_df['true_label']
    y_pred = results_df['predicted_label']
    
    # Track "unknown" predictions
    unknown_count = (y_pred == "unknown").sum()
    print(f"Number of 'unknown' classifications: {unknown_count}")
    
    # Filter out unknown predictions for valid accuracy calculations
    y_true_filtered = y_true[y_pred != "unknown"]
    y_pred_filtered = y_pred[y_pred != "unknown"]
    
    if not y_true_filtered.empty and not y_pred_filtered.empty:
        print(classification_report(y_true_filtered, y_pred_filtered, labels=y_true_filtered.unique()))
        print("Accuracy:", accuracy_score(y_true_filtered, y_pred_filtered))
    else:
        print("No valid classifications to report.")

    print("\nOverall Accuracy:", accuracy_score(y_true, y_pred))

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred, labels=y_true.unique())
    
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=y_true.unique(), yticklabels=y_true.unique())
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix for GPT-4o Classification")
    plt.show()

    # Bar Chart of Correct vs Incorrect Classifications
    correct_classifications = (y_true == y_pred).sum()
    incorrect_classifications = len(y_true) - correct_classifications
    
    plt.figure(figsize=(6, 4))
    plt.bar(["Correctly Classified", "Incorrectly Classified"], [correct_classifications, incorrect_classifications], color=['green', 'red'])
    plt.ylabel('Number of Images')
    plt.title('GPT-4o Classification Accuracy')
    plt.show()

# Example usage
dataset_path = os.path.join("Fetal Brain Abnormalities Ultrasound.v1i.multiclass", "test", "_classes - _classes.csv")
if os.path.exists(dataset_path):
    evaluate_gpt4o(dataset_path)
else:
    print("Dataset file not found! Ensure you provide a valid CSV.")
# Out:
# GPT-4o Classification Results:
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-mild-ventriculomegaly-18c_aug_2_png_jpg.rf.1a7978b80bec239d05c1870f509b7aaa.jpg
# True Label: mild ventriculomegaly
# Predicted Label: severe ventriculomegaly
# Analysis: The ultrasound image shows an abnormally large lateral ventricle, indicating an excess of cerebrospinal fluid accumulation. The enlarged ventricle suggests disruption in normal brain anatomy.
#
# Final Classification: Severe Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-intracranial-hemorrdge-34a_aug_4_png_jpg.rf.28478dd858a77613009654fc5c607fe6.jpg
# True Label: intracranial hemorrhage
# Predicted Label: severe ventriculomegaly
# Analysis: The ultrasound image shows a prominent enlargement of the ventricles within the fetal brain. The lateral ventricles appear significantly dilated. The presence of enlarged ventricles suggests an abnormal accumulation of cerebrospinal fluid.
#
# Final Classification: Severe Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Patient00709_Plane3_2_of_3_aug_3_png_jpg.rf.29b80ab6ed98c3dfaff4b207896d3200.jpg
# True Label: normal
# Predicted Label: hydranencephaly
# Analysis: The ultrasound image shows a bright, rounded structure within the cranial cavity. There is a significant amount of echogenic material present, suggestive of abnormal brain development. The presence of fluid spaces is noted, with reduced brain tissue visible.
#
# Based on these visual features:
#
# Final Classification: Hydranencephaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Patient00709_Plane3_1_of_3_aug_3_png_jpg.rf.1117a9081fbf9766dee6caad5459418c.jpg
# True Label: normal
# Predicted Label: moderate ventriculomegaly
# Analysis: The ultrasound image shows a cranial structure with an enlarged lateral ventricle, which seems to suggest an increase in the size of the fluid-filled spaces within the brain. The ventricles appear more prominent than usual, which could indicate dilatation.
#
# Final Classification: Moderate Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-moderate-ventriculomegaly-31c_aug_1_png_jpg.rf.0b5cc9b050f17d76ee5f113a39e66476.jpg
# True Label: moderate ventriculomegaly
# Predicted Label: mega cisterna magna
# Analysis: The ultrasound image shows evidence of an enlarged cisterna magna, which is characterized by dilation of the space behind the cerebellum. The remaining brain structures appear to be normally developed without significant abnormalities in the lateral ventricles or other areas.
#
# Final Classification: Mega Cisterna Magna
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-cerebellah-hypoplasia-36o_aug_5_png_jpg.rf.1651df9dd9ecc6c8b5377c505d18ab62.jpg
# True Label: cerebellar hypoplasia
# Predicted Label: hydranencephaly
# Analysis: The ultrasound image shows an absence of normal brain structures with replacement by fluid-filled spaces, suggestive of the absence of cerebral hemispheres. The cranial vault appears to be filled with fluid, indicating a lack of cerebral development.
#
# Final Classification: Hydranencephaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-mild-ventriculomegaly-24a_png_jpg.rf.0c5234956c0fae21df22aa4b827fcf40.jpg
# True Label: mild ventriculomegaly
# Predicted Label: moderate ventriculomegaly
# Analysis: The ultrasound image shows an enlarged lateral ventricle, which is more pronounced than what is typically seen in mild ventriculomegaly but not as extreme as severe ventriculomegaly. The ventricle appears dilated.
#
# Final Classification: Moderate ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-moderate-ventriculomegaly-26_aug_3_png_jpg.rf.18f8f1a5a31437eefd27bf993a6797b4.jpg
# True Label: moderate ventriculomegaly
# Predicted Label: moderate ventriculomegaly
# Analysis: The ultrasound image shows significantly enlarged lateral ventricles indicative of increased fluid accumulation. This suggests a pattern of ventriculomegaly. The degree of enlargement appears considerable, but not extreme, which warrants classification beyond mild ventriculomegaly while not fully reaching severe characteristics.
#
# Final Classification: Moderate Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-encephalocele1-23a_png_jpg.rf.13c875bdb4a8040639f40fdf598b45ba.jpg
# True Label: encephalocele
# Predicted Label: hydranencephaly
# Analysis: The ultrasound image shows an abnormal pattern characterized by a large fluid-filled cavity with minimal brain tissue, indicating significant lack of cerebral development. This appearance is consistent with the replacement of cerebral hemispheres by a large fluid-filled space.
#
# Final Classification: Hydranencephaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-severe-ventriculomegaly-26b_aug_0_png_jpg.rf.019a2d83374f6310290757098b8ac4fc.jpg
# True Label: severe ventriculomegaly
# Predicted Label: moderate ventriculomegaly
# Analysis: The ultrasound image shows an enlarged area within the brain that appears to be fluid-filled, indicating dilation of the lateral ventricles. The appearance suggests an increase in the size of the ventricles, which is characteristic of ventriculomegaly. Without a clear indication of severe size, the ventricular dilation seems to be beyond mild but not excessive, suggesting a moderate degree.
#
# Final Classification: Moderate Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-mild-ventriculomegaly-23a_aug_4_png_jpg.rf.265e1efd009ae0ffac6c6adfbeccedc0.jpg
# True Label: mild ventriculomegaly
# Predicted Label: severe ventriculomegaly
# Analysis: The ultrasound image shows an enlarged fluid-filled area in the fetal brain, which is suggestive of increased fluid accumulation. The lateral ventricles appear to be enlarged beyond what is typically expected.
#
# Final Classification: Severe Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-mild-ventriculomegaly-23b_aug_0_png_jpg.rf.2b303e68319f5a378e3f0cbfe12429ac.jpg
# True Label: mild ventriculomegaly
# Predicted Label: severe ventriculomegaly
# Analysis: The ultrasound image shows significant dilatation of the lateral ventricles. The enlarged ventricles suggest an excess of cerebrospinal fluid, which is a key feature of ventriculomegaly. The degree of enlargement appears to be quite pronounced.
#
# Final Classification: Severe Ventriculomegaly
# --------------------------------------------------------------------------------
# Filename: Fetal Brain Abnormalities Ultrasound.v1i.multiclass/test/Copy-of-severe-ventriculomegaly-18a_aug_2_png_jpg.rf.0d989138da29e84fd027b7885d5e1690.jpg
# True Label: severe ventriculomegaly
# Predicted Label: severe ventriculomegaly
# Analysis: The ultrasound image shows an enlarged ventricular system with dilated lateral ventricles, which suggests excess cerebrospinal fluid accumulation. The choroid plexus appears to be 'dangling,' indicative of increased ventricular size.
#
# Final Classification: Severe Ventriculomegaly
# --------------------------------------------------------------------------------
# Classification Report:
# Number of 'unknown' classifications: 0
#                            precision    recall  f1-score   support
#
#     mild ventriculomegaly       0.00      0.00      0.00         5
#   intracranial hemorrhage       0.00      0.00      0.00         1
# moderate ventriculomegaly       0.40      0.40      0.40         5
#            polymicrogyria       0.00      0.00      0.00         1
#             encephalocele       0.00      0.00      0.00         2
#     cerebellar hypoplasia       0.00      0.00      0.00         2
#                    normal       0.00      0.00      0.00         2
#   severe ventriculomegaly       0.10      0.50      0.17         2
#
#                 micro avg       0.19      0.15      0.17        20
#                 macro avg       0.06      0.11      0.07        20
#              weighted avg       0.11      0.15      0.12        20
#
# Accuracy: 0.15
#
# Overall Accuracy: 0.15
# /Users/ansha/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ansha/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ansha/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
